# %% [markdown]
# # Sprawdzian 1: Wczytywanie plików
#
# To notebook przygotowujący do pierwszego sprawdzianu z pracy z plikami tekstowymi.

# %% [markdown]
# ## Wstęp teoretyczny
#
# Plik to uporządkowany zbiór danych zapisany na dysku komputera. Najczęściej spotykamy pliki tekstowe, obrazy, filmy lub arkusze kalkulacyjne. W tym sprawdzianie skupiamy się na **plikach tekstowych**, które składają się z kolejnych linijek znaków. Naszym materiałem będzie poemat *Pan Tadeusz* Adama Mickiewicza w formacie `.txt`.
#
# Każda linijka kończy się niewidocznym znakiem nowej linii (`\n`). To właśnie ten znak sprawia, że następny fragment tekstu zaczyna się w nowym wierszu. Podczas pracy z plikami warto mieć świadomość jego obecności, aby prawidłowo dzielić i łączyć tekst.

# %% [markdown]
# ## Jak wczytać plik w Pythonie?
#
# Do otwierania plików używamy funkcji `open()`. Najbezpieczniej korzystać z instrukcji `with`, ponieważ automatycznie zamknie plik po zakończeniu pracy. **Zwróć uwagę na wcięcia** – wszystko, co ma działać na otwartym pliku, musi znajdować się wewnątrz bloku `with` i być wcięte o cztery spacje.

# %% [markdown]
# ### Skąd wziąć plik *Pan Tadeusz*?
#
# W repozytorium znajdziesz skrypt `pobierz_pan_tadeusz.py`, który pobiera aktualną wersję tekstu z serwisu Wolne Lektury. Wystarczy uruchomić go w katalogu z tym notebookiem (np. poleceniem `python pobierz_pan_tadeusz.py`), aby utworzyć plik `pan-tadeusz.txt`. To właśnie ten plik będziemy otwierać w dalszych przykładach.

# %%
# przykład: wczytanie całej zawartości pliku naraz
with open('pan-tadeusz.txt', 'r', encoding='utf-8') as plik:
    zawartosc = plik.read()  # wszystko trafia do jednego łańcucha znaków
print(zawartosc)  # można go dalej analizować lub wyświetlić

# %% [markdown]
# Powyższy kod zakłada, że plik `pan-tadeusz.txt` znajduje się w tym samym folderze co nasz skrypt lub notebook. Jeżeli plik leży gdzie indziej, należy podać pełną ścieżkę lub zmodyfikować zmienną z nazwą pliku.

# %% [markdown]
# ## Wczytanie wszystkich linijek na raz
#
# Metoda `readlines()` zwraca listę, w której każda pozycja to kolejna linia z pliku łącznie ze znakiem nowej linii. Gdy zależy nam na tekście bez końcowych znaków, możemy użyć `read().splitlines()`.

# %%
with open('pan-tadeusz.txt', 'r', encoding='utf-8') as plik:
    wszystkie_linie = plik.readlines()
print(wszystkie_linie)  # lista linijek razem ze znakami "\n"

with open('pan-tadeusz.txt', 'r', encoding='utf-8') as plik:
    wszystkie_linie_bez_znaku = plik.read().splitlines()
print(wszystkie_linie_bez_znaku)  # lista linijek bez znaków nowej linii

# %% [markdown]
# ## Wczytywanie linijka po linijce w pętli `for`
#
# Jeśli plik jest duży lub chcemy przetwarzać dane krok po kroku, lepiej wczytywać linijki po kolei. Tutaj również pilnujemy wcięć – ciało pętli `for` musi być wcięte względem nagłówka. `enumerate()` pomoże numerować linie, a `strip()` usunie zbędne znaki, w tym końcowy znak nowej linii.

# %%
with open('pan-tadeusz.txt', 'r', encoding='utf-8') as plik:
    for numer, linia in enumerate(plik, start=1):
        czysta_linijka = linia.strip()  # usuwamy "\n" oraz ewentualne spacje z obu stron
        print(f'Linia {numer}: {czysta_linijka}')

# %% [markdown]
# ## Zadania do sprawdzianu
#
# Poniżej znajdziesz pięć propozycji zadań o rosnącym poziomie trudności, wszystkie oparte na tekście *Pana Tadeusza* zapisanym w pliku `pan-tadeusz.txt`. Daj znać, które z nich chcesz wykorzystać lub jak je zmodyfikować. Po każdej instrukcji znajdziesz komórkę z komentarzami podpowiadającymi kolejne kroki.

# %% [markdown]
# ### Zadanie 1. Pierwsze spotkanie z plikiem
#
# Otwórz plik i wypisz pierwsze dziesięć linijek tekstu w dokładnie takiej kolejności, w jakiej występują. Pamiętaj, że całe działanie musi odbywać się wewnątrz bloku `with`.

# %%
# Zadanie 1: Pierwsze spotkanie z plikiem
# Krok 1: Otwórz plik 'pan-tadeusz.txt' w trybie odczytu ('r') z kodowaniem 'utf-8' używając instrukcji 'with'.
# Krok 2: Wczytaj kolejne linie z pliku i zapisz tylko pierwszych dziesięć z nich.
# Krok 3: Wypisz zebrane linie dokładnie w tej kolejności, w jakiej zostały odczytane.
# Krok 4: Upewnij się, że wszystkie operacje na pliku znajdują się wewnątrz bloku 'with'.

# %% [markdown]
# ### Zadanie 2. Wyszukiwanie słów-kluczy
#
# Przejdź po linijkach i policz, ile z nich zawiera słowo `Litwo` (niezależnie od wielkości liter). Wynik wypisz na końcu.

# %%
# Zadanie 2: Wyszukiwanie słów-kluczy
# Krok 1: Otwórz plik 'pan-tadeusz.txt' do odczytu w bloku 'with'.
# Krok 2: Iteruj po każdej linijce w pliku i porównuj tekst w sposób nieczuły na wielkość liter (np. użyj 'lower()').
# Krok 3: Zlicz liczbę linijek zawierających słowo 'litwo'.
# Krok 4: Po zakończeniu pętli wypisz podsumowanie z uzyskanym wynikiem.

# %% [markdown]
# ### Zadanie 3. Analiza nagłówków ksiąg
#
# Wyszukaj nagłówki rozpoczynające się od słowa `KSIĘGA` i wypisz je wraz z numerami w kolejności występowania. To zadanie uczy filtrowania linijek po wzorcu.

# %%
# Zadanie 3: Analiza nagłówków ksiąg
# Krok 1: Otwórz plik 'pan-tadeusz.txt' do odczytu w bloku 'with'.
# Krok 2: Iteruj po liniach, numerując je funkcją 'enumerate' rozpoczynając od 1.
# Krok 3: Sprawdź, czy dana linia po usunięciu białych znaków zaczyna się od słowa 'KSIĘGA'.
# Krok 4: Jeśli warunek jest spełniony, zapamiętaj numer i treść linii, aby wypisać je po zakończeniu pętli lub od razu wypisz wyniki.

# %% [markdown]
# ### Zadanie 4. Statystyka słów bohatera
#
# Wczytaj cały tekst i oblicz, ile razy pojawia się imię `Tadeusz` (również w różnych wielkościach liter). Wynik przedstaw w zwięzłej informacji tekstowej.

# %%
# Zadanie 4: Statystyka słów bohatera
# Krok 1: Otwórz plik 'pan-tadeusz.txt' w bloku 'with' i wczytaj całą zawartość do jednej zmiennej (np. metodą 'read').
# Krok 2: Przekształć tekst do jednej wielkości liter, aby porównania były nieczułe na wielkość liter.
# Krok 3: Zlicz wystąpienia słowa 'tadeusz' w przygotowanym tekście.
# Krok 4: Przygotuj komunikat tekstowy prezentujący wynik i go wypisz.

# %% [markdown]
# ### Zadanie 5. Raport o strukturze tekstu
#
# Przygotuj raport zawierający: łączną liczbę linijek, liczbę znaków (z uwzględnieniem i bez uwzględnienia znaków nowej linii) oraz średnią długość linijki. Opcjonalnie wskaż trzy najdłuższe linijki wraz z ich numerami.

# %%
# Zadanie 5: Raport o strukturze tekstu
# Krok 1: Otwórz plik 'pan-tadeusz.txt' w bloku 'with' i wczytaj wszystkie linie do listy.
# Krok 2: Oblicz łączną liczbę linijek oraz łączną liczbę znaków, zarówno z uwzględnieniem, jak i bez znaków nowej linii.
# Krok 3: Wyznacz średnią długość linijki na podstawie zebranych danych.
# Krok 4: (Opcjonalnie) Odszukaj trzy najdłuższe linie i zapisz ich numery oraz długości.
# Krok 5: Wypisz czytelny raport z uzyskanych statystyk.
